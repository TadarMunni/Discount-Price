# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error
from math import sqrt

import scipy.stats as stats
import pylab

# %%
df = pd.read_csv('train.csv')
df
# Out:
#           id                                              title  Rating  \
# 0      16695  Fashionable & Comfortable Bellies For Women  (...     3.9
# 1       5120  Combo Pack of 4 Casual Shoes Sneakers For Men ...     3.8
# 2      18391         Cilia Mode Leo Sneakers For Women  (White)     4.4
# 3        495                            Men Black Sports Sandal     4.2
# 4      16408                            Men Green Sports Sandal     3.9
# ...      ...                                                ...     ...
# 15725  16554                          Women Maroon Heels Sandal     4.3
# 15726  19600                      Women Multicolor Flats Sandal     3.9
# 15727   6733                            Women Navy Flats Sandal     3.7
# 15728   3889                           Red Chief Men's Sneakers     3.9
# 15729  13682                           Slip On For Men  (Brown)     5.0
#
#       maincateg  platform  price1  actprice1 Offer %  norating1  noreviews1  \
# 0         Women  Flipkart     698        999  30.13%       38.0         7.0
# 1           Men  Flipkart     999       1999  50.03%      531.0        69.0
# 2         Women  Flipkart    2749       4999  45.01%       17.0         4.0
# 3           Men  Flipkart     518        724  15.85%    46413.0      6229.0
# 4           Men  Flipkart    1379       2299  40.02%       77.0         3.0
# ...         ...       ...     ...        ...     ...        ...         ...
# 15725     Women  Flipkart     567       1199  52.71%      807.0       114.0
# 15726     Women  Flipkart     499        998  50.00%      246.0        34.0
# 15727     Women  Flipkart     329        499  34.07%        NaN        18.0
# 15728       Men    Amazon    2249       4499  50.01%      750.0       479.0
# 15729       Men  Flipkart    1539       2799  45.02%        8.0         1.0
#
#        star_5f  star_4f  star_3f  star_2f  star_1f  fulfilled1
# 0         17.0      9.0      6.0        3        3           0
# 1        264.0     92.0     73.0       29       73           1
# 2         11.0      3.0      2.0        1        0           1
# 3       1045.0  12416.0   5352.0      701     4595           1
# 4         35.0     21.0      7.0        7        7           1
# ...        ...      ...      ...      ...      ...         ...
# 15725    485.0    177.0     61.0       41       43           0
# 15726    120.0     45.0     37.0       16       28           1
# 15727      NaN      NaN     20.0       10       15           1
# 15728     13.0      6.0     10.0       25       47           1
# 15729      8.0      0.0      0.0        0        0           1
#
# [15730 rows x 16 columns]

# %%
df.describe()
# Out:
#                  id        Rating        price1     actprice1      norating1  \
# count  15730.000000  15730.000000  15730.000000  15730.000000   15052.000000
# mean   10479.541577      4.012873    688.070693   1369.286777    3057.660776
# std     6080.166276      0.298440    649.409586   1240.900227   11846.965689
# min        3.000000      0.000000     69.000000     42.000000       1.000000
# 25%     5212.000000      3.900000    349.000000    699.000000      63.000000
# 50%    10458.500000      4.000000    474.000000    999.000000     308.000000
# 75%    15766.750000      4.200000    699.000000   1299.000000    1526.000000
# max    20973.000000      5.000000   5998.000000  13499.000000  289973.000000
#
#          noreviews1        star_5f       star_4f       star_3f       star_2f  \
# count  15152.000000   15142.000000  15191.000000  15499.000000  15730.000000
# mean     423.976307    1585.239466    655.923310    357.260662    155.085188
# std     1768.230384    6177.476241   2855.735531   1402.246610    558.650254
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        9.000000      30.000000     12.000000      7.000000      3.000000
# 50%       44.000000     150.000000     60.000000     34.000000     17.000000
# 75%      215.000000     788.000000    300.000000    172.000000     77.000000
# max    45448.000000  151193.000000  74037.000000  34978.000000  11705.000000
#
#             star_1f    fulfilled1
# count  15730.000000  15730.000000
# mean     275.500572      0.601526
# std      958.589075      0.489600
# min        0.000000      0.000000
# 25%        6.000000      0.000000
# 50%       30.000000      1.000000
# 75%      140.000000      1.000000
# max    18060.000000      1.000000

# %%
df.nunique()
# Out:
# id            15730
# title          4782
# Rating           34
# maincateg         2
# platform          2
# price1         1478
# actprice1       885
# Offer %        2530
# norating1      2770
# noreviews1     1122
# star_5f        2196
# star_4f        1448
# star_3f        1107
# star_2f         759
# star_1f        1001
# fulfilled1        2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# Rating          0
# maincateg     526
# platform        0
# price1          0
# actprice1       0
# Offer %         0
# norating1     678
# noreviews1    578
# star_5f       588
# star_4f       539
# star_3f       231
# star_2f         0
# star_1f         0
# fulfilled1      0
# dtype: int64

# %%
df.dtypes
# Out:
# id              int64
# title          object
# Rating        float64
# maincateg      object
# platform       object
# price1          int64
# actprice1       int64
# Offer %        object
# norating1     float64
# noreviews1    float64
# star_5f       float64
# star_4f       float64
# star_3f       float64
# star_2f         int64
# star_1f         int64
# fulfilled1      int64
# dtype: object

# %%
df.shape
# Out:
# (15730, 16)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#drop id  and Offer %(Not present in final test data of hackathon)
df.drop(['id', 'Offer %'], axis=1, inplace=True)

# %% [markdown]
# ### Data Visualization

# %%
#Boxplot
df_box = df.drop(["title", "maincateg", "platform"], axis=1)
plt.figure(figsize = (23, 13))
# sns.boxplot(x=df_box)
sns.boxplot(x="variable", y="value", data = pd.melt(df_box))

# sns.set(rc = {'figure.figsize':(26,13)})
# Out:
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %%
sns.pairplot(df)

# %%
#Correlation plot
 
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
df = df.drop('norating1', axis=1) #correlated

# %% [markdown]
# ## Handling Missing Values

# %%
df.isnull().sum()
# Out:
# title           0
# Rating          0
# maincateg     526
# platform        0
# price1          0
# actprice1       0
# noreviews1    578
# star_5f       588
# star_4f       539
# star_3f       231
# star_2f         0
# star_1f         0
# fulfilled1      0
# dtype: int64

# %% [markdown]
# Many of the <b>maincateg</b> null values can be filled using <b>title</b> column

# %%
df.maincateg.value_counts()
# Out:
# Women    8781
# Men      6423
# Name: maincateg, dtype: int64

# %%
df.loc[df['title'].str.upper().str.contains('WOMEN') & df['maincateg'].isnull(), 'maincateg'] = 'Women'
df.loc[df['title'].str.upper().str.contains('MEN' or 'BOY') & df['maincateg'].isnull(), 'maincateg'] = 'Men'
df['maincateg'].isnull().sum()
# Out:
# 57

# %%
df['maincateg'].value_counts()
# Out:
# Women    9059
# Men      6614
# Name: maincateg, dtype: int64

# %%
df.loc[df['maincateg'].isnull(), 'maincateg'] = 'Women'
print(df['maincateg'].isnull().sum())
print(df['maincateg'].unique())
# Out:
# 0
# ['Women' 'Men']

# %%
df.drop('title', axis=1, inplace=True)

# %% [markdown]
# Star ratings and norating1 null values

# %%
#handle numerical missing values
from sklearn.impute import SimpleImputer
cols = [ 'noreviews1', 'star_5f','star_4f', 'star_3f']
imp = SimpleImputer(strategy = "median")
df[cols] = imp.fit_transform(df[cols])
df.isnull().sum()
# Out:
# Rating        0
# maincateg     0
# platform      0
# price1        0
# actprice1     0
# noreviews1    0
# star_5f       0
# star_4f       0
# star_3f       0
# star_2f       0
# star_1f       0
# fulfilled1    0
# dtype: int64

# %%
Y = df['price1']
X = df.drop(['price1'], axis=1)

# %% [markdown]
# Encoding of categorical variables

# %%
X_t = pd.get_dummies(X)
X_t.head()
# Out:
#    Rating  actprice1  noreviews1  star_5f  star_4f  star_3f  star_2f  star_1f  \
# 0     3.9        999         7.0     17.0      9.0      6.0        3        3
# 1     3.8       1999        69.0    264.0     92.0     73.0       29       73
# 2     4.4       4999         4.0     11.0      3.0      2.0        1        0
# 3     4.2        724      6229.0   1045.0  12416.0   5352.0      701     4595
# 4     3.9       2299         3.0     35.0     21.0      7.0        7        7
#
#    fulfilled1  maincateg_Men  maincateg_Women  platform_Amazon  \
# 0           0              0                1                0
# 1           1              1                0                0
# 2           1              0                1                0
# 3           1              1                0                0
# 4           1              1                0                0
#
#    platform_Flipkart
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled=pd.DataFrame(scaler.fit_transform(X_t))
X_scaled.columns = X_t.columns

# %% [markdown]
# ### Model Implementation

# %%
# Metric
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import RandomizedSearchCV

RMSE_test = []
RMSE_train = []
Model_Name = []

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train ,y_test = train_test_split( X_scaled, Y, test_size=0.25,  random_state=42 )

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge


model_list = [RandomForestRegressor(),XGBRegressor(),DecisionTreeRegressor(),ElasticNet(), SVR(),
              GradientBoostingRegressor(),
              AdaBoostRegressor(),Lasso(),LinearRegression(),Ridge()]

for model in model_list:
    print(model)
    model.fit(X_train, y_train)

    print('Test Set --------------')
    y_predictions = model.predict(X_test)
    mse = mean_squared_error(y_test, y_predictions)
    rmse = np.sqrt(mse)

    RMSE_test.append(rmse)
    Model_Name.append( 'RandomForestRegressor' )

    print('Root Mean Square Error : ', rmse )
    print('\n')

    print('Train Set --------------')
    y_predictions = model.predict(X_train)
    mse = mean_squared_error(y_train, y_predictions)
    rmse = np.sqrt(mse)
    RMSE_train.append(rmse)
    print('Root Mean Square Error : ', rmse )
    
    print('\n')
    print('\n')
    print("-------------------------------------------------------------------------------")
# Out:
# RandomForestRegressor()
# Test Set --------------
# Root Mean Square Error :  207.6912011789788
#
#
# Train Set --------------
# Root Mean Square Error :  80.94118090864197
#
#
#
#
# -------------------------------------------------------------------------------
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, gamma=None,
#              gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, predictor=None, random_state=None,
#              reg_alpha=None, reg_lambda=None, ...)
# Test Set --------------
# Root Mean Square Error :  217.21926583116436
#
#
# Train Set --------------
# Root Mean Square Error :  110.26378890663698
#
#
#
#
# -------------------------------------------------------------------------------
# DecisionTreeRegressor()
# Test Set --------------
# Root Mean Square Error :  289.2594598652116
#
#
# Train Set --------------
# Root Mean Square Error :  28.255042637286824
#
#
#
#
# -------------------------------------------------------------------------------
# ElasticNet()
# Test Set --------------
# Root Mean Square Error :  349.6408272993883
#
#
# Train Set --------------
# Root Mean Square Error :  343.78121892057356
#
#
#
#
# -------------------------------------------------------------------------------
# SVR()
# Test Set --------------
# Root Mean Square Error :  515.349496020766
#
#
# Train Set --------------
# Root Mean Square Error :  499.1234610783662
#
#
#
#
# -------------------------------------------------------------------------------
# GradientBoostingRegressor()
# Test Set --------------
# Root Mean Square Error :  255.89476144662845
#
#
# Train Set --------------
# Root Mean Square Error :  243.6798427759716
#
#
#
#
# -------------------------------------------------------------------------------
# AdaBoostRegressor()
# Test Set --------------
# Root Mean Square Error :  302.53149827453416
#
#
# Train Set --------------
# Root Mean Square Error :  300.7127171705081
#
#
#
#
# -------------------------------------------------------------------------------
# Lasso()
# Test Set --------------
# Root Mean Square Error :  287.7024301240978
#
#
# Train Set --------------
# Root Mean Square Error :  289.0707370647381
#
#
#
#
# -------------------------------------------------------------------------------
# LinearRegression()
# Test Set --------------
# Root Mean Square Error :  287.4416707815865
#
#
# Train Set --------------
# Root Mean Square Error :  288.90534792902264
#
#
#
#
# -------------------------------------------------------------------------------
# Ridge()
# Test Set --------------
# Root Mean Square Error :  287.44345950718565
#
#
# Train Set --------------
# Root Mean Square Error :  288.9053715779662
#
#
#
#
# -------------------------------------------------------------------------------

# %% [markdown]
# We can see that Random Forest Regressor is doing best here

# %%
# RandomForest
# Number of trees in random forest
n_estimators = [100, 200, 400, 500, 800, 1000, 1200 ]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rand_reg = RandomForestRegressor()

# %%
random_CV = RandomizedSearchCV(estimator = rand_reg, param_distributions = random_grid,cv=3, 
                               n_iter=50, verbose=5, random_state=42)

# %%
# random_CV.fit(X_scaled, Y)

# %%
# random_CV.best_estimator_

# %%
rand_final = RandomForestRegressor(bootstrap=False, max_depth=40, max_features='sqrt',
                      n_estimators=200);
rand_final.fit(X_scaled, Y)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=40, max_features='sqrt',
#                       n_estimators=200)

# %%
df_test = pd.read_csv('test.csv')

# %%
x_test = df_test.drop(['id', 'norating1'], axis =1)
x_test
# Out:
#                                                   title  Rating maincateg  \
# 0                               Casuals For Men  (Blue)     3.8       Men
# 1                              Women Black Flats Sandal     3.9     Women
# 2                              Women Gold Wedges Sandal     3.9     Women
# 3     Men's Height Increasing High Heel Formal Party...     3.9       Men
# 4                                Loafers For Men  (Tan)     3.9       Men
# ...                                                 ...     ...       ...
# 5239                       Women Off White Flats Sandal     NaN     Women
# 5240                             Slip On For Men  (Tan)     3.9       Men
# 5241                            Women Grey Heels Sandal     3.8     Women
# 5242  Womens Casual Comfort Stylish Black High Heel ...     3.9     Women
# 5243    ZAPATOZ Women's Casual PU Leather Sneaker Shoes     3.9     Women
#
#       platform  actprice1  noreviews1  star_5f  star_4f  star_3f  star_2f  \
# 0     Flipkart        999        3543  14238.0     4295     3457     1962
# 1     Flipkart        499         404   1458.0      657      397      182
# 2     Flipkart        999          52    229.0       70       71       33
# 3     Flipkart       2999          40    141.0       51       49       17
# 4     Flipkart        999         326   1265.0      414      293      143
# ...        ...        ...         ...      ...      ...      ...      ...
# 5239  Flipkart        699         153      NaN      323      155       62
# 5240  Flipkart       1993          56    350.0       37       60        5
# 5241  Flipkart        999         135    574.0      290      172       94
# 5242  Flipkart        499         574   2384.0      974      648      328
# 5243    Amazon        749           5     28.0        0        0        0
#
#       star_1f  fulfilled1
# 0      3976.0           1
# 1       321.0           1
# 2        46.0           1
# 3        32.0           1
# 4       308.0           0
# ...       ...         ...
# 5239      NaN           1
# 5240     37.0           0
# 5241    150.0           0
# 5242    533.0           0
# 5243     72.0           1
#
# [5244 rows x 12 columns]

# %%
x_test.isnull().sum()
# Out:
# title           0
# Rating        203
# maincateg      67
# platform        0
# actprice1       0
# noreviews1      0
# star_5f        68
# star_4f         0
# star_3f         0
# star_2f         0
# star_1f       186
# fulfilled1      0
# dtype: int64

# %%
x_test['Rating'].fillna(x_test.Rating.median(), inplace=True)
x_test['star_1f'].fillna(x_test.star_1f.median(), inplace=True)
x_test['star_5f'].fillna(x_test.star_5f.median(), inplace=True)

# %%
x_test.loc[x_test['title'].str.upper().str.contains('WOMEN') & x_test['maincateg'].isnull(), 'maincateg'] = 'Women'
x_test.loc[x_test['title'].str.upper().str.contains('MEN' or 'BOY') & x_test['maincateg'].isnull(), 'maincateg'] = 'Men'
x_test['maincateg'].isnull().sum()
# Out:
# 7

# %%
x_test['maincateg'].value_counts()
# Out:
# Women    3068
# Men      2169
# Name: maincateg, dtype: int64

# %%
x_test.loc[x_test['maincateg'].isnull(), 'maincateg'] = 'Women'

# %%
x_test.isnull().sum()
# Out:
# title         0
# Rating        0
# maincateg     0
# platform      0
# actprice1     0
# noreviews1    0
# star_5f       0
# star_4f       0
# star_3f       0
# star_2f       0
# star_1f       0
# fulfilled1    0
# dtype: int64

# %%
x_test = x_test.drop('title', axis=1)

# %%
x_test = pd.get_dummies(x_test)
x_test.head()
# Out:
#    Rating  actprice1  noreviews1  star_5f  star_4f  star_3f  star_2f  star_1f  \
# 0     3.8        999        3543  14238.0     4295     3457     1962   3976.0
# 1     3.9        499         404   1458.0      657      397      182    321.0
# 2     3.9        999          52    229.0       70       71       33     46.0
# 3     3.9       2999          40    141.0       51       49       17     32.0
# 4     3.9        999         326   1265.0      414      293      143    308.0
#
#    fulfilled1  maincateg_Men  maincateg_Women  platform_Amazon  \
# 0           1              1                0                0
# 1           1              0                1                0
# 2           1              0                1                0
# 3           1              1                0                0
# 4           0              1                0                0
#
#    platform_Flipkart
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %%
X_test_scaled=pd.DataFrame(scaler.transform(x_test))
X_test_scaled.columns = x_test.columns
X_test_scaled.dtypes
# Out:
# Rating               float64
# actprice1            float64
# noreviews1           float64
# star_5f              float64
# star_4f              float64
# star_3f              float64
# star_2f              float64
# star_1f              float64
# fulfilled1           float64
# maincateg_Men        float64
# maincateg_Women      float64
# platform_Amazon      float64
# platform_Flipkart    float64
# dtype: object

# %%
predictions =pd.DataFrame(df_test["id"])
predictions['price1'] = rand_final.predict(X_test_scaled)
predictions
# Out:
#          id       price1
# 0      2242   431.000000
# 1     20532   284.000000
# 2     10648   499.000000
# 3     20677  1076.300000
# 4     12593   405.345000
# ...     ...          ...
# 5239  14033   412.072917
# 5240    297   730.478333
# 5241  18733   389.000000
# 5242   6162   189.000000
# 5243  13574   751.875000
#
# [5244 rows x 2 columns]

# %%
submission = predictions.to_csv("prediction_results.csv", index = False)
